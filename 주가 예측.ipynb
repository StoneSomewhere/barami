# %%
import numpy as np
from tensorflow.keras.models import Sequential, load_model
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers
import os
from LoadData import load_data
import tensorflow_addons as tfa

K.clear_session()

home = "C:/Users/Young Chan Jo/Documents/퀀트/"

model = load_model(home+ "./모델 백업/" +"GRU2_1h_0.5018_0.9152.h5")
model.compile(optimizer='Radam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

#사용 전에 NewDataScrap.py를 먼저 수행하여 새 파일을 받아옴
resource = home+"./DATA/"+"./3bull_uptodate"
files = os.listdir(resource)

for file in files:
    if "X_" not in file: continue
    file = file.split('_')[1:]
    tail = '_'.join(file)
    print(tail)
    X = path+"X_"+tail
    Y = path+"Y_"+tail
    
    model.evaluate(np.load(X), np.load(Y), batch_size=1024)

# %%
#leverage 들은 2018년 10월부터의 데이터다. webl의 경우 2019년 11월부터의 데이터다.

# %%
import numpy as np
from tensorflow.keras.models import Sequential, load_model
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers
import os
from LoadData import load_data
import tensorflow_addons as tfa

K.clear_session()

path = '../모델 백업/'
model = load_model(path+"GRU1_1h_0.7402_0.4923.h5")
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#model.summary()



path="../DATA/test/"
files = os.listdir(path)

for file in files:
    if "X_" not in file: continue
    file = file.split('_')[1:]
    tail = '_'.join(file)
    print(tail)
    X = path+"X_"+tail
    Y = path+"Y_"+tail
    #print(np.load(X), np.load(Y))
    model.evaluate(np.load(X), np.load(Y), batch_size=1)
# Out:
# CURE_5_down.npy
# 25/25 [==============================] - 2s 30ms/step - loss: 0.7966 - accuracy: 0.1600
# CURE_5_up.npy
# 3/3 [==============================] - 0s 31ms/step - loss: 0.7168 - accuracy: 0.0000e+00
# DFEN_5_down.npy
# 19/19 [==============================] - 1s 29ms/step - loss: 0.6132 - accuracy: 0.7368
# DFEN_5_up.npy
# 14/14 [==============================] - 0s 30ms/step - loss: 0.6620 - accuracy: 0.9286
# DRN_5_down.npy
# 35/35 [==============================] - 1s 29ms/step - loss: 0.6587 - accuracy: 0.5714 0s - loss: 0.5641 - accu
# DRN_5_up.npy
# 3/3 [==============================] - 0s 29ms/step - loss: 0.6398 - accuracy: 1.0000
# DUSL_5_down.npy
# 24/24 [==============================] - 1s 28ms/step - loss: 0.6562 - accuracy: 0.5833
# DUSL_5_up.npy
# 14/14 [==============================] - 0s 28ms/step - loss: 0.4364 - accuracy: 1.0000
# EDC_5_down.npy
# 39/39 [==============================] - 1s 28ms/step - loss: 0.7569 - accuracy: 0.4872ETA: 0s - l
# ...

# %%
result.history.keys()
min(result.history['val_accuracy'])

# %%
import numpy as np
from tensorflow.keras.models import Sequential, load_model
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers
import os
from LoadData import load_data
import tensorflow_addons as tfa

K.clear_session()

path = '../모델 백업/'
model = load_model(path+"GRU1_1h_0.4480_0.7805.h5")
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#model.summary()



path="../DATA/test/"
files = os.listdir(path)

for file in files:
    if "X_" not in file: continue
    if not (("_5_" in file) or ("_5_" in file)): continue
    file = file.split('_')[1:]
    tail = '_'.join(file)
    print(tail)
    X = path+"X_"+tail
    Y = path+"Y_"+tail
    
    model.evaluate(np.load(X), np.load(Y), batch_size=1)

# %%
import numpy as np
from tensorflow.keras.models import Sequential, load_model
import tensorflow.keras.backend as K
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, TerminateOnNaN
import os
from LoadData import load_data
import tensorflow_addons as tfa

K.clear_session()


for i in [9,11,12,14]:
    print(i)
    X_test = np.load("../DATA/X_1h_test2_trend_%d.npy"%i)
    Y_test = np.load("../DATA/Y_1h_test2_trend_%d.npy"%i)
    #X_recent = np.load("../DATA/X_train_1hw3_leverage_test.npy")
    #Y_recent = np.load("../DATA/Y_train_1hw3_leverage_test.npy")
    


    #path="./"
    path="../모델 백업/"
    files = os.listdir(path)


    for file in files:
        if ".h5" not in file: continue
        print(file)
        model = load_model(path+file)
        model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
        model.evaluate(X_test, Y_test, batch_size=1024)
        #model.evaluate(X_recent, Y_recent, batch_size=1024)
    
        #model.summary()
# Out:
# 9
# GRU2_1h_0.6121_0.6872.h5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6013 - accuracy: 0.6786
# 11
# GRU2_1h_0.6121_0.6872.h5
# 1/1 [==============================] - 2s 2s/step - loss: 0.5843 - accuracy: 0.7020
# 12
# GRU2_1h_0.6121_0.6872.h5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6046 - accuracy: 0.6827
# 14
# GRU2_1h_0.6121_0.6872.h5
# 1/1 [==============================] - 2s 2s/step - loss: 0.6146 - accuracy: 0.6778
